# %%
from CGCNN_MT.datamodule.prepare_data import prepare_data
from CGCNN_MT.datamodule.prepare_data import make_prepared_data, get_logger
from pathlib import Path
from tqdm import tqdm
import multiprocessing as mp
import shutil
from functools import partial
import pandas as pd
import json
import warnings
from sklearn.model_selection import train_test_split
import numpy as np
import shutil
warnings.filterwarnings("ignore", category=UserWarning, module="pymatgen.io.cif")
warnings.filterwarnings("ignore", category=UserWarning, module="moftransformer.utils.prepare_data")
warnings.filterwarnings("ignore", category=UserWarning, module="ase.io.cif")

# %%
src_csv = "./raw_data/WS24v2/features/features_and_labels.csv"
src_cif_dir1 = Path("./raw_data/WS24v2/data_sets/WS14s/CIFs")
src_cif_dir2 = Path("./raw_data/WS24v2/data_sets/WS24s/CIFs")
tgt_root_dir = Path("./CGCNN_MT/data/WS24")

tgt_root_dir.mkdir(exist_ok=True, parents=True)

# %%
print(len(list(src_cif_dir1.glob('*.cif'))))
print(len(list(src_cif_dir2.glob('*.cif'))))
# Out:
# 181
# 911

# %%
in_df = pd.read_csv(src_csv)
in_df.head(2)
# Out:
#   MOF_name data_set  water_label  acid_label  base_label  boiling_label  \
# 0   ACOFUU    WS24s            2           0           0              0
# 1   ACOGAB    WS24s            2           0           0              0
#
#         Di       Df      Dif      VSA  ...  f-lig-T-2  f-lig-T-3  f-lig-Z-0  \
# 0  7.99458  6.67411  7.99458  2280.10  ...     1696.0     2024.0     2032.0
# 1  5.20086  3.89327  4.83563  1877.51  ...     1696.0     2024.0     2032.0
#
#    f-lig-Z-1  f-lig-Z-2  f-lig-Z-3  f-lig-chi-0  f-lig-chi-1  f-lig-chi-2  \
# 0     4616.0     6536.0     7248.0     540.5536     1176.932    1966.5344
# 1     4616.0     6536.0     7248.0     540.5536     1176.932    1966.5344
#
#    f-lig-chi-3
# 0    2565.1968
# 1    2565.1968
#
# [2 rows x 165 columns]

# %% [markdown]
# ## Move cif files

# %%
mofs_withot_file = []
tgt_cif_dir = tgt_root_dir/"cifs"
# if tgt_cif_dir.exists():
#     shutil.rmtree(tgt_cif_dir)
tgt_cif_dir.mkdir(exist_ok=True)
for i in range(len(in_df)):
    n = in_df.iloc[i]["MOF_name"]
    dataset = in_df.iloc[i]["data_set"]
    if dataset == "WS14s":
        cif_file = src_cif_dir1/f"{n}.cif"
    elif dataset == "WS24s":
        cif_file = src_cif_dir2/f"{n}.cif"
    if not cif_file.exists():
        print(f"{cif_file} does not exist.")
        mofs_withot_file.append(n)
        continue
    shutil.copy(cif_file, tgt_cif_dir)

# %%
if len(mofs_withot_file) > 0:
    print(f"There are {len(mofs_withot_file)} MOFs without CIF files.")
    with open(tgt_root_dir/"mofs_withot_cif.txt", "w") as f:
        f.write("\n".join(mofs_withot_file))

# %% [markdown]
# ### Reneragete zeo++ and RACs features for WS24 datasets.

# %%
from CGCNN_MT.datamodule import clean_cif
import subprocess
import os

## clean cifs
for task in  ["WS24"]:
    task_dir = Path("/home/dharunkraja/Desktop/D/MOFSNN_D/CGCNN_MT/data/WS24")
    cif_dir = task_dir/"cifs"
    output_dir = task_dir/"clean_cifs"
    total_cifs = len(list(cif_dir.glob("*.cif")))
    print(f"Processing {total_cifs} CIF files...")
    
    # Monitor progress during cleaning
    with tqdm(total=total_cifs, desc="Cleaning CIFs") as pbar:
        # Get initial count
        initial_count = len(list(output_dir.glob("*.cif"))) if output_dir.exists() else 0
        
        clean_cif.main(cif_dir, output_dir, log_file=task_dir/"clean_cif.log", santize=True, n_cpus=7)
        
        # Final count
        processed_cifs = len(list(output_dir.glob("*.cif")))
        pbar.update(processed_cifs - initial_count)
    
    print(f"Processed: {processed_cifs}/{total_cifs} CIF files")

# %%
from pathlib import Path

# configure directories
cifs_dir = Path("/home/dharunkraja/Desktop/D/MOFSNN_D/CGCNN_MT/data/WS24/cifs")
clean_dir = Path("/home/dharunkraja/Desktop/D/MOFSNN_D/CGCNN_MT/data/WS24/clean_cifs")
out_file = clean_dir.parent / "missing_in_clean_cifs.txt"

if not cifs_dir.exists():
    print(f"Source CIF directory does not exist: {cifs_dir}")
elif not clean_dir.exists():
    print(f"Clean CIF directory does not exist: {clean_dir}")
else:
    src_files = sorted([p.name for p in cifs_dir.glob("*.cif")])
    clean_files_set = {p.name for p in clean_dir.glob("*.cif")}

    missing = [f for f in src_files if f not in clean_files_set]

    print(f"Total CIFs in source: {len(src_files)}")
    print(f"Total CIFs in clean dir: {len(clean_files_set)}")
    print(f"Missing CIFs in clean dir: {len(missing)}")

    if missing:
        out_file.write_text("\n".join(missing))
        print(f"Wrote list of missing files to: {out_file}")
        print("First 10 missing files:", missing[:10])
    else:
        if out_file.exists():
            out_file.unlink()
        print("All CIF files are present in the clean_cifs directory.")
# Out:
# Total CIFs in source: 1092
# Total CIFs in clean dir: 1092
# Missing CIFs in clean dir: 0
# All CIF files are present in the clean_cifs directory.

# %%
import subprocess
import os
import random
from pathlib import Path

## generate features - test with one random file first
for task in ["WS24"]:
    task_dir = Path("./CGCNN_MT/data/WS24")
    clean_cif_dir = task_dir / "clean_cifs"
    work_dir = Path("./ML/featuring")
    
    # Get all clean cif files and select one random file
    clean_cif_files = list(clean_cif_dir.glob("*.cif"))
    
    if clean_cif_files:
        random_cif = random.choice(clean_cif_files)
        print(f"Testing feature generation with: {random_cif.name}")
        
        # Use absolute paths to avoid path issues
        abs_clean_cif_dir = clean_cif_dir.resolve()
        abs_work_dir = work_dir.resolve()
        
        print(f"Clean CIF dir: {abs_clean_cif_dir}")
        print(f"Work dir: {abs_work_dir}")
        
        # Create a temp directory with just one file
        temp_test_dir = work_dir / "temp_test_cifs"
        temp_test_dir.mkdir(exist_ok=True, parents=True)
        
        # Copy single file to temp directory
        temp_cif_path = temp_test_dir / random_cif.name
        shutil.copy(random_cif, temp_cif_path)
        
        abs_temp_dir = temp_test_dir.resolve()
        
        # Run feature generation on single file
        cmd = f"python feature_generation.py --cif_dir {abs_temp_dir} --prob_radius 1.86"
        print(f"Running command: {cmd}")
        
        process = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            shell=True,
            env=os.environ.copy(),
            cwd=str(abs_work_dir)
        )
        
        stdout, stderr = process.communicate()
        
        if process.returncode == 0:
            print("✓ Test feature generation completed successfully")
            print(f"Output: {stdout.decode()}")
        else:
            print(f"✗ Feature generation failed with return code: {process.returncode}")
            print(f"Error: {stderr.decode()}")
        
        # Cleanup temp directory
        if temp_cif_path.exists():
            os.remove(temp_cif_path)
        if temp_test_dir.exists():
            shutil.rmtree(temp_test_dir)
    else:
        print("No clean CIF files found in directory")
# Out:
# Testing feature generation with: KOMGEZ.cif
# Clean CIF dir: /home/dharunkraja/Desktop/D/MOFSNN_D/CGCNN_MT/data/WS24/clean_cifs
# Work dir: /home/dharunkraja/Desktop/D/MOFSNN_D/ML/featuring
# Running command: python feature_generation.py --cif_dir /home/dharunkraja/Desktop/D/MOFSNN_D/ML/featuring/temp_test_cifs --prob_radius 1.86
# ✓ Test feature generation completed successfully
# Output: Generating features for all MOFs using 96 cores.
# The current MOF is KOMGEZ. Number 1 of 1.
# The primitive cell of KOMGEZ could not be found.
# unsuccessful_featurizations is []

# %%
import subprocess
import os
import random
from pathlib import Path
## generate features for all CIF files
task_dir = Path("./CGCNN_MT/data/WS24")
clean_cif_dir = task_dir / "clean_cifs"
work_dir = Path("./ML/featuring")

# Use absolute paths to avoid path issues
abs_clean_cif_dir = clean_cif_dir.resolve()
abs_work_dir = work_dir.resolve()

print(f"Clean CIF dir: {abs_clean_cif_dir}")
print(f"Work dir: {abs_work_dir}")

# Get all clean cif files
clean_cif_files = list(clean_cif_dir.glob("*.cif"))
print(f"Found {len(clean_cif_files)} CIF files to process")

if clean_cif_files:
    # Run feature generation on all files in clean_cifs directory
    cmd = f"python feature_generation.py --cif_dir {abs_clean_cif_dir} --prob_radius 1.86"
    print(f"Running command: {cmd}")
    
    process = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        shell=True,
        env=os.environ.copy(),
        cwd=str(abs_work_dir)
    )
    
    stdout, stderr = process.communicate()
    
    if process.returncode == 0:
        print("✓ Feature generation completed successfully")
        print(f"Output: {stdout.decode()}")
    else:
        print(f"✗ Feature generation failed with return code: {process.returncode}")
        print(f"Error: {stderr.decode()}")
else:
    print("No clean CIF files found in directory")
# Out:
# Clean CIF dir: /home/dharunkraja/Desktop/D/MOFSNN_D/CGCNN_MT/data/WS24/clean_cifs
# Work dir: /home/dharunkraja/Desktop/D/MOFSNN_D/ML/featuring
# Found 1092 CIF files to process
# Running command: python feature_generation.py --cif_dir /home/dharunkraja/Desktop/D/MOFSNN_D/CGCNN_MT/data/WS24/clean_cifs --prob_radius 1.86
# ✓ Feature generation completed successfully
# Output: Generating features for all MOFs using 96 cores.
# RAC generation already complete for ACOFUU. Continuing to next MOF.
# The current MOF is ACOFUU. Number 1 of 1092.
# RAC generation already complete for ACOGAB. Continuing to next MOF.
# The current MOF is ACOGAB. Number 2 of 1092.
# RAC generation already complete for ACOGEF. Continuing to next MOF.
# The current MOF is ACOGEF. Number 3 of 1092.
# RAC generation already complete for ADABUE. Continuing to next MOF.
# The current MOF is ADABUE. Number 4 of 1092.
# RAC generation already complete for AFEJUQ. Continuing to next MOF.
# The current MOF is AFEJUQ. Number 5 of 1092.
# RAC generation already complete for AGUBUA. Continuing to next MOF.
# The current MOF is AGUBUA. Number 6 of 1092.
# RAC generation already complete for AKOXIJ. Continuing to next MOF.
# The current MOF is AKOXIJ. Number 7 of 1092.
# RAC generation already complete for ALAMUW. Continuing to next MOF.
# The current MOF is ALAMUW. Number 8 of 1092.
# RAC generation already complete for AMEJIM. Continuing to next MOF.
# The current MOF is AMEJIM. Number 9 of 1092.
# RAC generation already complete for AMEJOS. Continuing to next MOF.
# The current MOF is AMEJOS. Number 10 of 1092.
# RAC generation already complete for APUVIS. Continuing to next MOF.
# The current MOF is APUVIS. Number 11 of 1092.
# RAC generation already complete for AQOLID. Continuing to next MOF.
# The current MOF is AQOLID. Number 12 of 1092.
# RAC generation already complete for ARAHIM02. Continuing to next MOF.
# The current MOF is ARAHIM02. Number 13 of 1092.
# RAC generation already complete for ARUHUS. Continuing to next MOF.
# The current MOF is ARUHUS. Number 14 of 1092.
# RAC generation already complete for ASEBAD. Continuing to next MOF.
# The current MOF is ASEBAD. Number 15 of 1092.
# RAC generation already complete for ASECUY. Continuing to next MOF.
# The current MOF is ASECUY. Number 16 of 1092.
# RAC generation already complete for ASOYOY. Continuing to next MOF.
# The current MOF is ASOYOY. Number 17 of 1092.
# RAC generation already complete for ATAHUA. Continuing to next MOF.
# The current MOF is ATAHUA. Number 18 of 1092.
# RAC generation already complete for ATAJAI. Continuing to next MOF.
# The current MOF is ATAJAI. Number 19 of 1092.
# RAC generation already complete for ATAYAX. Continuing to next MOF.
# The current MOF is ATAYAX. Number 20 of 1092.
# RAC generation already complete for ATAYEB. Continuing to next MOF.
# The current MOF is ATAYEB. Number 21 of 1092.
# RAC generation already complete for ATEJOA. Continuing to next MOF.
# The current MOF is ATEJOA. Number 22 of 1092.
# RAC generation already complete for AVIPAX. Continuing to next MOF.
# The current MOF is AVIPAX. Number 23 of 1092.
# RAC generation already complete for AVIPEB. Continuing to next MOF.
# The current MOF is AVIPEB. Number 24 of 1092.
# RAC generation already complete for AVUHEF. Continuing to next MOF.
# The current MOF is AVUHEF. Number 25 of 1092.
# RAC generation already complete for AVUHIJ. Continuing to next MOF.
# The current MOF is AVUHIJ. Number 26 of 1092.
# RAC generation already complete for AVUHOP. Continuing to next MOF.
# The current MOF is AVUHOP. Number 27 of 1092.
# RAC generation already complete for AVUHUV. Continuing to next MOF.
# The current MOF is AVUHUV. Number 28 of 1092.
# RAC generation already complete for AVUJAD. Continuing to next MOF.
# The current MOF is AVUJAD. Number 29 of 1092.
# RAC generation already complete for AVUJEH. Continuing to next MOF.
# The current MOF is AVUJEH. Number 30 of 1092.
# RAC generation already complete for AVUJIL. Continuing to next MOF.
# The current MOF is AVUJIL. Number 31 of 1092.
# RAC generation already complete for AVUJOR. Continuing to next MOF.
# The current MOF is AVUJOR. Number 32 of 1092.
# RAC generation already complete for AVUJUX. Continuing to next MOF.
# The current MOF is AVUJUX. Number 33 of 1092.
# RAC generation already complete for AVUKAE. Continuing to next MOF.
# The current MOF is AVUKAE. Number 34 of 1092.
# RAC generation already complete for AVUKEI. Continuing to next MOF.
# The current MOF is AVUKEI. Number 35 of 1092.
# RAC generation already complete for AVUKIM. Continuing to next MOF.
# The current MOF is AVUKIM. Number 36 of 1092.
# RAC generation already complete for AWEDOW. Continuing to next MOF.
# The current MOF is AWEDOW. Number 37 of 1092.
# RAC generation already complete for AWEDUC. Continuing to next MOF.
# The current MOF is AWEDUC. Number 38 of 1092.
# RAC generation already complete for AWIBAL. Continuing to next MOF.
# The current MOF is AWIBAL. Number 39 of 1092.
# RAC generation already complete for AWIBEP. Continuing to next MOF.
# The current MOF is AWIBEP. Number 40 of 1092.
# RAC generation already complete for AWIBIT. Continuing to next MOF.
# The current MOF is AWIBIT. Number 41 of 1092.
# RAC generation already complete for AXOHEA. Continuing to next MOF.
# The current MOF is AXOHEA. Number 42 of 1092.
# RAC generation already complete for AZAVII. Continuing to next MOF.
# The current MOF is AZAVII. Number 43 of 1092.
# RAC generation already complete for AZAVOO. Continuing to next MOF.
# The current MOF is AZAVOO. Number 44 of 1092.
# RAC generation already complete for AZAVUU. Continuing to next MOF.
# The current MOF is AZAVUU. Number 45 of 1092.
# RAC generation already complete for AZAWAB. Continuing to next MOF.
# The current MOF is AZAWAB. Number 46 of 1092.
# RAC generation already complete for Al_OH_1-4-NDC. Continuing to next MOF.
# The current MOF is Al_OH_1-4-NDC. Number 47 of 1092.
# RAC generation already complete for AlaZnCl. Continuing to next MOF.
# The current MOF is AlaZnCl. Number 48 of 1092.
# RAC generation already complete for AlaZnOAc. Continuing to next MOF.
# The current MOF is AlaZnOAc. Number 49 of 1092.
# RAC generation already complete for BADXAI. Continuing to next MOF.
# The current MOF is BADXAI. Number 50 of 1092.
# RAC generation already complete for BAFBIW. Continuing to next MOF.
# The current MOF is BAFBIW. Number 51 of 1092.
# RAC generation already complete for BAFBOC. Continuing to next MOF.
# The current MOF is BAFBOC. Number 52 of 1092.
# RAC generation already complete for BAFCAP. Continuing to next MOF.
# The current MOF is BAFCAP. Number 53 of 1092.
# RAC generation already complete for BEDHOJ. Continuing to next MOF.
# The current MOF is BEDHOJ. Number 54 of 1092.
# RAC generation already complete for BELYIC. Continuing to next MOF.
# The current MOF is BELYIC. Number 55 of 1092.
# RAC generation already complete for BELYUO. Continuing to next MOF.
# The current MOF is BELYUO. Number 56 of 1092.
# RAC generation already complete for BICPOT. Continuing to next MOF.
# The current MOF is BICPOT. Number 57 of 1092.
# RAC generation already complete for BIQHEQ. Continuing to next MOF.
# The current MOF is BIQHEQ. Number 58 of 1092.
# RAC generation already complete for BIQHIU. Continuing to next MOF.
# The current MOF is BIQHIU. Number 59 of 1092.
# RAC generation already complete for BIQHOA. Continuing to next MOF.
# The current MOF is BIQHOA. Number 60 of 1092.
# RAC generation already complete for BIRKUK. Continuing to next MOF.
# The current MOF is BIRKUK. Number 61 of 1092.
# RAC generation already complete for BIRLAR. Continuing to next MOF.
# The current MOF is BIRLAR. Number 62 of 1092.
# RAC generation already complete for BIRLEV. Continuing to next MOF.
# The current MOF is BIRLEV. Number 63 of 1092.
# RAC generation already complete for BIRLIZ. Continuing to next MOF.
# The current MOF is BIRLIZ. Number 64 of 1092.
# RAC generation already complete for BOHWUS. Continuing to next MOF.
# The current MOF is BOHWUS. Number 65 of 1092.
# RAC generation already complete for BOPWIO. Continuing to next MOF.
# The current MOF is BOPWIO. Number 66 of 1092.
# RAC generation already complete for BUCTUQ. Continuing to next MOF.
# The current MOF is BUCTUQ. Number 67 of 1092.
# RAC generation already complete for BUCVAY. Continuing to next MOF.
# The current MOF is BUCVAY. Number 68 of 1092.
# RAC generation already complete for BUCVEC. Continuing to next MOF.
# The current MOF is BUCVEC. Number 69 of 1092.
# RAC generation already complete for BUCVIG. Continuing to next MOF.
# The current MOF is BUCVIG. Number 70 of 1092.
# RAC generation already complete for BUCWAZ. Continuing to next MOF.
# The current MOF is BUCWAZ. Number 71 of 1092.
# RAC generation already complete for BUNKUS. Continuing to next MOF.
# The current MOF is BUNKUS. Number 72 of 1092.
# RAC generation already complete for BUQWER. Continuing to next MOF.
# The current MOF is BUQWER. Number 73 of 1092.
# RAC generation already complete for BUVHEH. Continuing to next MOF.
# The current MOF is BUVHEH. Number 74 of 1092.
# RAC generation already complete for Bio-MOF-11. Continuing to next MOF.
# The current MOF is Bio-MOF-11. Number 75 of 1092.
# RAC generation already complete for Bio-MOF-12. Continuing to next MOF.
# The current MOF is Bio-MOF-12. Number 76 of 1092.
# RAC generation already complete for Bio-MOF-13. Continuing to next MOF.
# The current MOF is Bio-MOF-13. Number 77 of 1092.
# RAC generation already complete for Bio-MOF-14. Continuing to next MOF.
# The current MOF is Bio-MOF-14. Number 78 of 1092.
# RAC generation already complete for CALF-25-a. Continuing to next MOF.
# The current MOF is CALF-25-a. Number 79 of 1092.
# RAC generation already complete for CAU-10-CH3. Continuing to next MOF.
# The current MOF is CAU-10-CH3. Number 80 of 1092.
# RAC generation already complete for CAU-10-H. Continuing to next MOF.
# The current MOF is CAU-10-H. Number 81 of 1092.
# RAC generation already complete for CAU-10-NH2. Continuing to next MOF.
# The current MOF is CAU-10-NH2. Number 82 of 1092.
# RAC generation already complete for CAU-10-NO2. Continuing to next MOF.
# The current MOF is CAU-10-NO2. Number 83 of 1092.
# RAC generation already complete for CAU-10-OCH3. Continuing to next MOF.
# The current MOF is CAU-10-OCH3. Number 84 of 1092.
# RAC generation already complete for CAU-10-OH. Continuing to next MOF.
# The current MOF is CAU-10-OH. Number 85 of 1092.
# RAC generation already complete for CAU-10. Continuing to next MOF.
# The current MOF is CAU-10. Number 86 of 1092.
# RAC generation already complete for CAU-6. Continuing to next MOF.
# The current MOF is CAU-6. Number 87 of 1092.
# RAC generation already complete for CAVRAU. Continuing to next MOF.
# The current MOF is CAVRAU. Number 88 of 1092.
# RAC generation already complete for CAWZUX. Continuing to next MOF.
# The current MOF is CAWZUX. Number 89 of 1092.
# RAC generation already complete for CAYCIQ. Continuing to next MOF.
# The current MOF is CAYCIQ. Number 90 of 1092.
# RAC generation already complete for CEHKUW. Continuing to next MOF.
# The current MOF is CEHKUW. Number 91 of 1092.
# RAC generation already complete for CEHLAD. Continuing to next MOF.
# The current MOF is CEHLAD. Number 92 of 1092.
# RAC generation already complete for CIKCEG. Continuing to next MOF.
# The current MOF is CIKCEG. Number 93 of 1092.
# RAC generation already complete for CIKCIK. Continuing to next MOF.
# The current MOF is CIKCIK. Number 94 of 1092.
# RAC generation already complete for CIKCOQ. Continuing to next MOF.
# The current MOF is CIKCOQ. Number 95 of 1092.
# RAC generation already complete for CIMTEZ. Continuing to next MOF.
# The current MOF is CIMTEZ. Number 96 of 1092.
# RAC generation already complete for CIYZOA. Continuing to next MOF.
# The current MOF is CIYZOA. Number 97 of 1092.
# RAC generation already complete for CIYZUG. Continuing to next MOF.
# The current MOF is CIYZUG. Number 98 of 1092.
# RAC generation already complete for COMDOY. Continuing to next MOF.
# The current MOF is COMDOY. Number 99 of 1092.
# RAC generation already complete for COWLAC01. Continuing to next MOF.
# The current MOF is COWLAC01. Number 100 of 1092.
# RAC generation already complete for COWWOB. Continuing to next MOF.
# The current MOF is COWWOB. Number 101 of 1092.
# RAC generation already complete for COWWUH. Continuing to next MOF.
# The current MOF is COWWUH. Number 102 of 1092.
# RAC generation already complete for COWXAO. Continuing to next MOF.
# The current MOF is COWXAO. Number 103 of 1092.
# RAC generation already complete for COWXES. Continuing to next MOF.
# The current MOF is COWXES. Number 104 of 1092.
# RAC generation already complete for COWXIW. Continuing to next MOF.
# The current MOF is COWXIW. Number 105 of 1092.
# RAC generation already complete for COWXOC. Continuing to next MOF.
# The current MOF is COWXOC. Number 106 of 1092.
# RAC generation already complete for COYBUO. Continuing to next MOF.
# The current MOF is COYBUO. Number 107 of 1092.
# RAC generation already complete for COYCAV. Continuing to next MOF.
# The current MOF is COYCAV. Number 108 of 1092.
# RAC generation already complete for COYCEZ. Continuing to next MOF.
# The current MOF is COYCEZ. Number 109 of 1092.
# RAC generation already complete for COYCID. Continuing to next MOF.
# The current MOF is COYCID. Number 110 of 1092.
# RAC generation already complete for CUCFOX. Continuing to next MOF.
# The current MOF is CUCFOX. Number 111 of 1092.
# RAC generation already complete for CUK-1. Continuing to next MOF.
# The current MOF is CUK-1. Number 112 of 1092.
# RAC generation already complete for CUKWOV. Continuing to next MOF.
# The current MOF is CUKWOV. Number 113 of 1092.
# RAC generation already complete for CUKWUB. Continuing to next MOF.
# The current MOF is CUKWUB. Number 114 of 1092.
# RAC generation already complete for CUKXAI. Continuing to next MOF.
# The current MOF is CUKXAI. Number 115 of 1092.
# RAC generation already complete for CUKXEM. Continuing to next MOF.
# The current MOF is CUKXEM. Number 116 of 1092.
# RAC generation already complete for CUNFEX. Continuing to next MOF.
# The current MOF is CUNFEX. Number 117 of 1092.
# RAC generation already complete for CUNFIB. Continuing to next MOF.
# The current MOF is CUNFIB. Number 118 of 1092.
# RAC generation already complete for CUNFOH. Continuing to next MOF.
# The current MOF is CUNFOH. Number 119 of 1092.
# RAC generation already complete for CUNFOH01. Continuing to next MOF.
# The current MOF is CUNFOH01. Number 120 of 1092.
# RAC generation already complete for CUNGAU. Continuing to next MOF.
# The current MOF is CUNGAU. Number 121 of 1092.
# RAC generation already complete for CUSDIE. Continuing to next MOF.
# The current MOF is CUSDIE. Number 122 of 1092.
# RAC generation already complete for CUTKIM. Continuing to next MOF.
# The current MOF is CUTKIM. Number 123 of 1092.
# RAC generation already complete for CUTKOS. Continuing to next MOF.
# The current MOF is CUTKOS. Number 124 of 1092.
# RAC generation already complete for CUTKUY. Continuing to next MOF.
# The current MOF is CUTKUY. Number 125 of 1092.
# RAC generation already complete for Cd2_L2_2_Br_2_H2O_3. Continuing to next MOF.
# The current MOF is Cd2_L2_2_Br_2_H2O_3. Number 126 of 1092.
# RAC generation already complete for CdZrSr. Continuing to next MOF.
# The current MOF is CdZrSr. Number 127 of 1092.
# RAC generation already complete for Cd_2-6-NDC_0_5_PCA. Continuing to next MOF.
# The current MOF is Cd_2-6-NDC_0_5_PCA. Number 128 of 1092.
# RAC generation already complete for Cd_L1_Cl_H2O. Continuing to next MOF.
# The current MOF is Cd_L1_Cl_H2O. Number 129 of 1092.
# RAC generation already complete for Cd_L2_Cl_H2O. Continuing to next MOF.
# The current MOF is Cd_L2_Cl_H2O. Number 130 of 1092.
# RAC generation already complete for Cd_L3_Cl_H2O_2. Continuing to next MOF.
# The current MOF is Cd_L3_Cl_H2O_2. Number 131 of 1092.
# RAC generation already complete for Co-DMOF. Continuing to next MOF.
# The current MOF is Co-DMOF. Number 132 of 1092.
# RAC generation already complete for Co-DOBDC. Continuing to next MOF.
# The current MOF is Co-DOBDC. Number 133 of 1092.
# RAC generation already complete for Co-NIC. Continuing to next MOF.
# The current MOF is Co-NIC. Number 134 of 1092.
# RAC generation already complete for Co_L13_2. Continuing to next MOF.
# The current MOF is Co_L13_2. Number 135 of 1092.
# RAC generation already complete for Cu-DMOF. Continuing to next MOF.
# The current MOF is Cu-DMOF. Number 136 of 1092.
# RAC generation already complete for Cu-EBTC. Continuing to next MOF.
# The current MOF is Cu-EBTC. Number 137 of 1092.
# RAC generation already complete for Cu-HF. Continuing to next MOF.
# The current MOF is Cu-HF. Number 138 of 1092.
# RAC generation already complete for Cu-MBTC. Continuing to next MOF.
# The current MOF is Cu-MBTC. Number 139 of 1092.
# RAC generation already complete for Cu2_TCMBT_BPP_mu3-OH. Continuing to next MOF.
# The current MOF is Cu2_TCMBT_BPP_mu3-OH. Number 140 of 1092.
# RAC generation already complete for DAFJOM. Continuing to next MOF.
# The current MOF is DAFJOM. Number 141 of 1092.
# RAC generation already complete for DAFYAN. Continuing to next MOF.
# The current MOF is DAFYAN. Number 142 of 1092.
# RAC generation already complete for DAFYOB. Continuing to next MOF.
# The current MOF is DAFYOB. Number 143 of 1092.
# RAC generation already complete for DAGJAZ. Continuing to next MOF.
# The current MOF is DAGJAZ. Number 144 of 1092.
# RAC generation already complete for DAGJED. Continuing to next MOF.
# The current MOF is DAGJED. Number 145 of 1092.
# RAC generation already complete for DANVAQ. Continuing to next MOF.
# The current MOF is DANVAQ. Number 146 of 1092.
# RAC generation already complete for DANVEU. Continuing to next MOF.
# The current MOF is DANVEU. Number 147 of 1092.
# RAC generation already complete for DANVIY. Continuing to next MOF.
# The current MOF is DANVIY. Number 148 of 1092.
# RAC generation already complete for DARCOQ. Continuing to next MOF.
# The current MOF is DARCOQ. Number 149 of 1092.
# RAC generation already complete for DEJCEB. Continuing to next MOF.
# The current MOF is DEJCEB. Number 150 of 1092.
# RAC generation already complete for DEJCIF. Continuing to next MOF.
# The current MOF is DEJCIF. Number 151 of 1092.
# RAC generation already complete for DEYMOL. Continuing to next MOF.
# The current MOF is DEYMOL. Number 152 of 1092.
# RAC generation already complete for DOFQEV. Continuing to next MOF.
# The current MOF is DOFQEV. Number 153 of 1092.
# RAC generation already complete for DOFQIZ. Continuing to next MOF.
# The current MOF is DOFQIZ. Number 154 of 1092.
# RAC generation already complete for DOFQOF. Continuing to next MOF.
# The current MOF is DOFQOF. Number 155 of 1092.
# RAC generation already complete for DOFQUL. Continuing to next MOF.
# The current MOF is DOFQUL. Number 156 of 1092.
# RAC generation already complete for DOFRAS. Continuing to next MOF.
# The current MOF is DOFRAS. Number 157 of 1092.
# RAC generation already complete for DOFREW. Continuing to next MOF.
# The current MOF is DOFREW. Number 158 of 1092.
# RAC generation already complete for DONNEA. Continuing to next MOF.
# The current MOF is DONNEA. Number 159 of 1092.
# RAC generation already complete for DONXOV. Continuing to next MOF.
# The current MOF is DONXOV. Number 160 of 1092.
# RAC generation already complete for DONXUB. Continuing to next MOF.
# The current MOF is DONXUB. Number 161 of 1092.
# RAC generation already complete for DUKXAK. Continuing to next MOF.
# The current MOF is DUKXAK. Number 162 of 1092.
# RAC generation already complete for DUKXEO. Continuing to next MOF.
# The current MOF is DUKXEO. Number 163 of 1092.
# RAC generation already complete for DUKXIS. Continuing to next MOF.
# The current MOF is DUKXIS. Number 164 of 1092.
# RAC generation already complete for DUKXOY. Continuing to next MOF.
# The current MOF is DUKXOY. Number 165 of 1092.
# RAC generation already complete for DUKXUE. Continuing to next MOF.
# The current MOF is DUKXUE. Number 166 of 1092.
# RAC generation already complete for DUKYAL. Continuing to next MOF.
# The current MOF is DUKYAL. Number 167 of 1092.
# RAC generation already complete for DUKYEP. Continuing to next MOF.
# The current MOF is DUKYEP. Number 168 of 1092.
# RAC generation already complete for DUKYIT. Continuing to next MOF.
# The current MOF is DUKYIT. Number 169 of 1092.
# RAC generation already complete for DUKYOZ. Continuing to next MOF.
# The current MOF is DUKYOZ. Number 170 of 1092.
# RAC generation already complete for DULBUJ. Continuing to next MOF.
# The current MOF is DULBUJ. Number 171 of 1092.
# RAC generation already complete for DULCAQ. Continuing to next MOF.
# The current MOF is DULCAQ. Number 172 of 1092.
# RAC generation already complete for DULCIY. Continuing to next MOF.
# The current MOF is DULCIY. Number 173 of 1092.
# RAC generation already complete for DUXLEP. Continuing to next MOF.
# The current MOF is DUXLEP. Number 174 of 1092.
# RAC generation already complete for EBITAL. Continuing to next MOF.
# The current MOF is EBITAL. Number 175 of 1092.
# RAC generation already complete for EDIKEH. Continuing to next MOF.
# The current MOF is EDIKEH. Number 176 of 1092.
# RAC generation already complete for EDOVEA. Continuing to next MOF.
# The current MOF is EDOVEA. Number 177 of 1092.
# RAC generation already complete for EDOVIE. Continuing to next MOF.
# The current MOF is EDOVIE. Number 178 of 1092.
# RAC generation already complete for EGIKUB01. Continuing to next MOF.
# The current MOF is EGIKUB01. Number 179 of 1092.
# RAC generation already complete for EJIQIZ. Continuing to next MOF.
# The current MOF is EJIQIZ. Number 180 of 1092.
# RAC generation already complete for ELEREU. Continuing to next MOF.
# The current MOF is ELEREU. Number 181 of 1092.
# RAC generation already complete for ELERIY. Continuing to next MOF.
# The current MOF is ELERIY. Number 182 of 1092.
# RAC generation already complete for ELEROE. Continuing to next MOF.
# The current MOF is ELEROE. Number 183 of 1092.
# RAC generation already complete for ELOZUC. Continuing to next MOF.
# The current MOF is ELOZUC. Number 184 of 1092.
# RAC generation already complete for ELUBAQ. Continuing to next MOF.
# The current MOF is ELUBAQ. Number 185 of 1092.
# RAC generation already complete for ELUBEU. Continuing to next MOF.
# The current MOF is ELUBEU. Number 186 of 1092.
# RAC generation already complete for ELUBOE. Continuing to next MOF.
# The current MOF is ELUBOE. Number 187 of 1092.
# RAC generation already complete for EPEXEE. Continuing to next MOF.
# The current MOF is EPEXEE. Number 188 of 1092.
# RAC generation already complete for EPEXII. Continuing to next MOF.
# The current MOF is EPEXII. Number 189 of 1092.
# RAC generation already complete for EPEXOO. Continuing to next MOF.
# The current MOF is EPEXOO. Number 190 of 1092.
# RAC generation already complete for EPEXUU. Continuing to next MOF.
# The current MOF is EPEXUU. Number 191 of 1092.
# RAC generation already complete for EPEYAB. Continuing to next MOF.
# The current MOF is EPEYAB. Number 192 of 1092.
# RAC generation already complete for EPOMUT. Continuing to next MOF.
# The current MOF is EPOMUT. Number 193 of 1092.
# RAC generation already complete for EPONAA. Continuing to next MOF.
# The current MOF is EPONAA. Number 194 of 1092.
# RAC generation already complete for EPONEE. Continuing to next MOF.
# The current MOF is EPONEE. Number 195 of 1092.
# RAC generation already complete for EPONII. Continuing to next MOF.
# The current MOF is EPONII. Number 196 of 1092.
# RAC generation already complete for EPONOO. Continuing to next MOF.
# The current MOF is EPONOO. Number 197 of 1092.
# RAC generation already complete for EQUMUA. Continuing to next MOF.
# The current MOF is EQUMUA. Number 198 of 1092.
# RAC generation already complete for EQUNAH. Continuing to next MOF.
# The current MOF is EQUNAH. Number 199 of 1092.
# RAC generation already complete for EQUNEL. Continuing to next MOF.
# The current MOF is EQUNEL. Number 200 of 1092.
# RAC generation already complete for EQUNIP. Continuing to next MOF.
# The current MOF is EQUNIP. Number 201 of 1092.
# RAC generation already complete for ERIGER. Continuing to next MOF.
# The current MOF is ERIGER. Number 202 of 1092.
# RAC generation already complete for ERIGUH. Continuing to next MOF.
# The current MOF is ERIGUH. Number 203 of 1092.
# RAC generation already complete for ERIHIW. Continuing to next MOF.
# The current MOF is ERIHIW. Number 204 of 1092.
# RAC generation already complete for ERIHOC. Continuing to next MOF.
# The current MOF is ERIHOC. Number 205 of 1092.
# RAC generation already complete for ESARAT. Continuing to next MOF.
# The current MOF is ESARAT. Number 206 of 1092.
# RAC generation already complete for ESAREX. Continuing to next MOF.
# The current MOF is ESAREX. Number 207 of 1092.
# RAC generation already complete for ESARIB. Continuing to next MOF.
# The current MOF is ESARIB. Number 208 of 1092.
# RAC generation already complete for ESAROH. Continuing to next MOF.
# The current MOF is ESAROH. Number 209 of 1092.
# RAC generation already complete for ESARUN. Continuing to next MOF.
# The current MOF is ESARUN. Number 210 of 1092.
# RAC generation already complete for ESASAU. Continuing to next MOF.
# The current MOF is ESASAU. Number 211 of 1092.
# RAC generation already complete for ESASEY. Continuing to next MOF.
# The current MOF is ESASEY. Number 212 of 1092.
# RAC generation already complete for ESIFIX. Continuing to next MOF.
# The current MOF is ESIFIX. Number 213 of 1092.
# RAC generation already complete for ESIGES. Continuing to next MOF.
# The current MOF is ESIGES. Number 214 of 1092.
# RAC generation already complete for EVOTIT. Continuing to next MOF.
# The current MOF is EVOTIT. Number 215 of 1092.
# RAC generation already complete for EWESEF. Continuing to next MOF.
# The current MOF is EWESEF. Number 216 of 1092.
# RAC generation already complete for EZILUV. Continuing to next MOF.
# The current MOF is EZILUV. Number 217 of 1092.
# RAC generation already complete for EZIMAC. Continuing to next MOF.
# The current MOF is EZIMAC. Number 218 of 1092.
# RAC generation already complete for EZIMIK. Continuing to next MOF.
# The current MOF is EZIMIK. Number 219 of 1092.
# RAC generation already complete for EZOFUV. Continuing to next MOF.
# The current MOF is EZOFUV. Number 220 of 1092.
# RAC generation already complete for EZOGAC. Continuing to next MOF.
# The current MOF is EZOGAC. Number 221 of 1092.
# RAC generation already complete for Eu-Cu. Continuing to next MOF.
# The current MOF is Eu-Cu. Number 222 of 1092.
# RAC generation already complete for FEFTUG. Continuing to next MOF.
# The current MOF is FEFTUG. Number 223 of 1092.
# RAC generation already complete for FEFVAO. Continuing to next MOF.
# The current MOF is FEFVAO. Number 224 of 1092.
# RAC generation already complete for FEFVES. Continuing to next MOF.
# The current MOF is FEFVES. Number 225 of 1092.
# RAC generation already complete for FEYDET. Continuing to next MOF.
# The current MOF is FEYDET. Number 226 of 1092.
# RAC generation already complete for FIJFAG. Continuing to next MOF.
# The current MOF is FIJFAG. Number 227 of 1092.
# RAC generation already complete for FIJFEK. Continuing to next MOF.
# The current MOF is FIJFEK. Number 228 of 1092.
# RAC generation already complete for FIVYOZ. Continuing to next MOF.
# The current MOF is FIVYOZ. Number 229 of 1092.
# RAC generation already complete for FIVYUF. Continuing to next MOF.
# The current MOF is FIVYUF. Number 230 of 1092.
# RAC generation already complete for FIVZAM. Continuing to next MOF.
# The current MOF is FIVZAM. Number 231 of 1092.
# RAC generation already complete for FIVZEQ. Continuing to next MOF.
# The current MOF is FIVZEQ. Number 232 of 1092.
# RAC generation already complete for FIVZIU. Continuing to next MOF.
# The current MOF is FIVZIU. Number 233 of 1092.
# RAC generation already complete for FIYDOH. Continuing to next MOF.
# The current MOF is FIYDOH. Number 234 of 1092.
# RAC generation already complete for FMOF-1. Continuing to next MOF.
# The current MOF is FMOF-1. Number 235 of 1092.
# RAC generation already complete for FOJLOH. Continuing to next MOF.
# The current MOF is FOJLOH. Number 236 of 1092.
# RAC generation already complete for FOJLUN. Continuing to next MOF.
# The current MOF is FOJLUN. Number 237 of 1092.
# RAC generation already complete for FOPPIJ01. Continuing to next MOF.
# The current MOF is FOPPIJ01. Number 238 of 1092.
# RAC generation already complete for FORPIM. Continuing to next MOF.
# The current MOF is FORPIM. Number 239 of 1092.
# RAC generation already complete for FORPOS. Continuing to next MOF.
# The current MOF is FORPOS. Number 240 of 1092.
# RAC generation already complete for FORPUY. Continuing to next MOF.
# The current MOF is FORPUY. Number 241 of 1092.
# RAC generation already complete for FORQAF. Continuing to next MOF.
# The current MOF is FORQAF. Number 242 of 1092.
# RAC generation already complete for FORQEJ. Continuing to next MOF.
# The current MOF is FORQEJ. Number 243 of 1092.
# RAC generation already complete for FORQIN. Continuing to next MOF.
# The current MOF is FORQIN. Number 244 of 1092.
# RAC generation already complete for FORVOY. Continuing to next MOF.
# The current MOF is FORVOY. Number 245 of 1092.
# RAC generation already complete for FORWAL. Continuing to next MOF.
# The current MOF is FORWAL. Number 246 of 1092.
# RAC generation already complete for FOTNIN. Continuing to next MOF.
# The current MOF is FOTNIN. Number 247 of 1092.
# RAC generation already complete for FOXPUE. Continuing to next MOF.
# The current MOF is FOXPUE. Number 248 of 1092.
# RAC generation already complete for FUJCOC01. Continuing to next MOF.
# The current MOF is FUJCOC01. Number 249 of 1092.
# RAC generation already complete for FUTKEL. Continuing to next MOF.
# The current MOF is FUTKEL. Number 250 of 1092.
# RAC generation already complete for FUWXUR. Continuing to next MOF.
# The current MOF is FUWXUR. Number 251 of 1092.
# RAC generation already complete for FUWYAY. Continuing to next MOF.
# The current MOF is FUWYAY. Number 252 of 1092.
# RAC generation already complete for FUYCAF. Continuing to next MOF.
# The current MOF is FUYCAF. Number 253 of 1092.
# RAC generation already complete for FUYCEJ. Continuing to next MOF.
# The current MOF is FUYCEJ. Number 254 of 1092.
# RAC generation already complete for FUYKER. Continuing to next MOF.
# The current MOF is FUYKER. Number 255 of 1092.
# RAC generation already complete for GAQYIH. Continuing to next MOF.
# The current MOF is GAQYIH. Number 256 of 1092.
# RAC generation already complete for GAYFOD. Continuing to next MOF.
# The current MOF is GAYFOD. Number 257 of 1092.
# RAC generation already complete for GAYFUJ. Continuing to next MOF.
# The current MOF is GAYFUJ. Number 258 of 1092.
# RAC generation already complete for GAYGAQ. Continuing to next MOF.
# The current MOF is GAYGAQ. Number 259 of 1092.
# RAC generation already complete for GAYGEU. Continuing to next MOF.
# The current MOF is GAYGEU. Number 260 of 1092.
# RAC generation already complete for GAYGIY. Continuing to next MOF.
# The current MOF is GAYGIY. Number 261 of 1092.
# RAC generation already complete for GAYGOE. Continuing to next MOF.
# The current MOF is GAYGOE. Number 262 of 1092.
# RAC generation already complete for GAZKOJ. Continuing to next MOF.
# The current MOF is GAZKOJ. Number 263 of 1092.
# RAC generation already complete for GAZKUP. Continuing to next MOF.
# The current MOF is GAZKUP. Number 264 of 1092.
# RAC generation already complete for GAZLAW. Continuing to next MOF.
# The current MOF is GAZLAW. Number 265 of 1092.
# RAC generation already complete for GECXUH03. Continuing to next MOF.
# The current MOF is GECXUH03. Number 266 of 1092.
# RAC generation already complete for GEFYUN. Continuing to next MOF.
# The current MOF is GEFYUN. Number 267 of 1092.
# RAC generation already complete for GEFZAU. Continuing to next MOF.
# The current MOF is GEFZAU. Number 268 of 1092.
# RAC generation already complete for GIKMOD03. Continuing to next MOF.
# The current MOF is GIKMOD03. Number 269 of 1092.
# RAC generation already complete for GIKMOD11. Continuing to next MOF.
# The current MOF is GIKMOD11. Number 270 of 1092.
# RAC generation already complete for GINTAA01. Continuing to next MOF.
# The current MOF is GINTAA01. Number 271 of 1092.
# RAC generation already complete for GIYSUD. Continuing to next MOF.
# The current MOF is GIYSUD. Number 272 of 1092.
# RAC generation already complete for GIYTAK. Continuing to next MOF.
# The current MOF is GIYTAK. Number 273 of 1092.
# RAC generation already complete for GIYTEO. Continuing to next MOF.
# The current MOF is GIYTEO. Number 274 of 1092.
# RAC generation already complete for GIYTIS. Continuing to next MOF.
# The current MOF is GIYTIS. Number 275 of 1092.
# RAC generation already complete for GIYTOY. Continuing to next MOF.
# The current MOF is GIYTOY. Number 276 of 1092.
# RAC generation already complete for GIZNOT. Continuing to next MOF.
# The current MOF is GIZNOT. Number 277 of 1092.
# RAC generation already complete for GORLIK. Continuing to next MOF.
# The current MOF is GORLIK. Number 278 of 1092.
# RAC generation already complete for GUCTAB. Continuing to next MOF.
# The current MOF is GUCTAB. Number 279 of 1092.
# RAC generation already complete for GUVCIJ. Continuing to next MOF.
# The current MOF is GUVCIJ. Number 280 of 1092.
# RAC generation already complete for GUVCOP. Continuing to next MOF.
# The current MOF is GUVCOP. Number 281 of 1092.
# RAC generation already complete for GUWDUY. Continuing to next MOF.
# The current MOF is GUWDUY. Number 282 of 1092.
# RAC generation already complete for HACDOH. Continuing to next MOF.
# The current MOF is HACDOH. Number 283 of 1092.
# RAC generation already complete for HACDUN. Continuing to next MOF.
# The current MOF is HACDUN. Number 284 of 1092.
# RAC generation already complete for HACRAH. Continuing to next MOF.
# The current MOF is HACRAH. Number 285 of 1092.
# RAC generation already complete for HACREL. Continuing to next MOF.
# The current MOF is HACREL. Number 286 of 1092.
# RAC generation already complete for HADDOI. Continuing to next MOF.
# The current MOF is HADDOI. Number 287 of 1092.
# RAC generation already complete for HAJQUH. Continuing to next MOF.
# The current MOF is HAJQUH. Number 288 of 1092.
# RAC generation already complete for HEBGUS. Continuing to next MOF.
# The current MOF is HEBGUS. Number 289 of 1092.
# RAC generation already complete for HEBHAZ. Continuing to next MOF.
# The current MOF is HEBHAZ. Number 290 of 1092.
# RAC generation already complete for HEBHED. Continuing to next MOF.
# The current MOF is HEBHED. Number 291 of 1092.
# RAC generation already complete for HEBHIH. Continuing to next MOF.
# The current MOF is HEBHIH. Number 292 of 1092.
# RAC generation already complete for HEBHON. Continuing to next MOF.
# The current MOF is HEBHON. Number 293 of 1092.
# RAC generation already complete for HEBHUT. Continuing to next MOF.
# The current MOF is HEBHUT. Number 294 of 1092.
# RAC generation already complete for HEBJAB. Continuing to next MOF.
# The current MOF is HEBJAB. Number 295 of 1092.
# RAC generation already complete for HEBJEF. Continuing to next MOF.
# The current MOF is HEBJEF. Number 296 of 1092.
# RAC generation already complete for HEBJIJ. Continuing to next MOF.
# The current MOF is HEBJIJ. Number 297 of 1092.
# RAC generation already complete for HEBJOP. Continuing to next MOF.
# The current MOF is HEBJOP. Number 298 of 1092.
# RAC generation already complete for HESVOR. Continuing to next MOF.
# The current MOF is HESVOR. Number 299 of 1092.
# RAC generation already complete for HIFGIO. Continuing to next MOF.
# The current MOF is HIFGIO. Number 300 of 1092.
# RAC generation already complete for HIFGOU. Continuing to next MOF.
# The current MOF is HIFGOU. Number 301 of 1092.
# RAC generation already complete for HIFGUA. Continuing to next MOF.
# The current MOF is HIFGUA. Number 302 of 1092.
# RAC generation already complete for HIFHAH. Continuing to next MOF.
# The current MOF is HIFHAH. Number 303 of 1092.
# RAC generation already complete for HIFHIP. Continuing to next MOF.
# The current MOF is HIFHIP. Number 304 of 1092.
# RAC generation already complete for HIFVUO01. Continuing to next MOF.
# The current MOF is HIFVUO01. Number 305 of 1092.
# RAC generation already complete for HIQKID. Continuing to next MOF.
# The current MOF is HIQKID. Number 306 of 1092.
# RAC generation already complete for HIQKOJ. Continuing to next MOF.
# The current MOF is HIQKOJ. Number 307 of 1092.
# RAC generation already complete for HIQPAA. Continuing to next MOF.
# The current MOF is HIQPAA. Number 308 of 1092.
# RAC generation already complete for HIQPEE. Continuing to next MOF.
# The current MOF is HIQPEE. Number 309 of 1092.
# RAC generation already complete for HIQPII. Continuing to next MOF.
# The current MOF is HIQPII. Number 310 of 1092.
# RAC generation already complete for HIQRAC. Continuing to next MOF.
# The current MOF is HIQRAC. Number 311 of 1092.
# RAC generation already complete for HISFUM. Continuing to next MOF.
# The current MOF is HISFUM. Number 312 of 1092.
# RAC generation already complete for HISGAT. Continuing to next MOF.
# The current MOF is HISGAT. Number 313 of 1092.
# RAC generation already complete for HISGEX. Continuing to next MOF.
# The current MOF is HISGEX. Number 314 of 1092.
# RAC generation already complete for HISGIB. Continuing to next MOF.
# The current MOF is HISGIB. Number 315 of 1092.
# RAC generation already complete for HIWKOO. Continuing to next MOF.
# The current MOF is HIWKOO. Number 316 of 1092.
# RAC generation already complete for HKUST-1. Continuing to next MOF.
# The current MOF is HKUST-1. Number 317 of 1092.
# RAC generation already complete for HOHMIB. Continuing to next MOF.
# The current MOF is HOHMIB. Number 318 of 1092.
# RAC generation already complete for HOMQUW. Continuing to next MOF.
# The current MOF is HOMQUW. Number 319 of 1092.
# RAC generation already complete for HOMRAD. Continuing to next MOF.
# The current MOF is HOMRAD. Number 320 of 1092.
# RAC generation already complete for HOMREH. Continuing to next MOF.
# The current MOF is HOMREH. Number 321 of 1092.
# RAC generation already complete for HOMRIL. Continuing to next MOF.
# The current MOF is HOMRIL. Number 322 of 1092.
# RAC generation already complete for HOQMIL04. Continuing to next MOF.
# The current MOF is HOQMIL04. Number 323 of 1092.
# RAC generation already complete for HOWRES. Continuing to next MOF.
# The current MOF is HOWRES. Number 324 of 1092.
# RAC generation already complete for HOWRIW. Continuing to next MOF.
# The current MOF is HOWRIW. Number 325 of 1092.
# RAC generation already complete for HOWROC. Continuing to next MOF.
# The current MOF is HOWROC. Number 326 of 1092.
# RAC generation already complete for HOWRUI. Continuing to next MOF.
# The current MOF is HOWRUI. Number 327 of 1092.
# RAC generation already complete for HOWSET. Continuing to next MOF.
# The current MOF is HOWSET. Number 328 of 1092.
# RAC generation already complete for HUCSEF. Continuing to next MOF.
# The current MOF is HUCSEF. Number 329 of 1092.
# RAC generation already complete for HUFKOK. Continuing to next MOF.
# The current MOF is HUFKOK. Number 330 of 1092.
# RAC generation already complete for HUFKUQ. Continuing to next MOF.
# The current MOF is HUFKUQ. Number 331 of 1092.
# RAC generation already complete for HUKZIW02. Continuing to next MOF.
# The current MOF is HUKZIW02. Number 332 of 1092.
# RAC generation already complete for HUVHIR. Continuing to next MOF.
# The current MOF is HUVHIR. Number 333 of 1092.
# RAC generation already complete for HUVHOX. Continuing to next MOF.
# The current MOF is HUVHOX. Number 334 of 1092.
# RAC generation already complete for HUWHOY. Continuing to next MOF.
# The current MOF is HUWHOY. Number 335 of 1092.
# RAC generation already complete for HUWHUE. Continuing to next MOF.
# The current MOF is HUWHUE. Number 336 of 1092.
# RAC generation already complete for HUXHEP. Continuing to next MOF.
# The current MOF is HUXHEP. Number 337 of 1092.
# RAC generation already complete for HUXHEP01. Continuing to next MOF.
# The current MOF is HUXHEP01. Number 338 of 1092.
# RAC generation already complete for HUXHIT. Continuing to next MOF.
# The current MOF is HUXHIT. Number 339 of 1092.
# RAC generation already complete for HUXHOZ. Continuing to next MOF.
# The current MOF is HUXHOZ. Number 340 of 1092.
# RAC generation already complete for HUXHUF. Continuing to next MOF.
# The current MOF is HUXHUF. Number 341 of 1092.
# RAC generation already complete for HUXHUF01. Continuing to next MOF.
# The current MOF is HUXHUF01. Number 342 of 1092.
# RAC generation already complete for HUYFAJ. Continuing to next MOF.
# The current MOF is HUYFAJ. Number 343 of 1092.
# RAC generation already complete for IDIWUN. Continuing to next MOF.
# The current MOF is IDIWUN. Number 344 of 1092.
# RAC generation already complete for IDIXAU. Continuing to next MOF.
# The current MOF is IDIXAU. Number 345 of 1092.
# RAC generation already complete for IFESOD. Continuing to next MOF.
# The current MOF is IFESOD. Number 346 of 1092.
# RAC generation already complete for IFESUJ. Continuing to next MOF.
# The current MOF is IFESUJ. Number 347 of 1092.
# RAC generation already complete for IGUFOH. Continuing to next MOF.
# The current MOF is IGUFOH. Number 348 of 1092.
# RAC generation already complete for IHOTAC. Continuing to next MOF.
# The current MOF is IHOTAC. Number 349 of 1092.
# RAC generation already complete for IHOTEG. Continuing to next MOF.
# The current MOF is IHOTEG. Number 350 of 1092.
# RAC generation already complete for ILEPEW. Continuing to next MOF.
# The current MOF is ILEPEW. Number 351 of 1092.
# RAC generation already complete for ILOTOT. Continuing to next MOF.
# The current MOF is ILOTOT. Number 352 of 1092.
# RAC generation already complete for IMIDZB10. Continuing to next MOF.
# The current MOF is IMIDZB10. Number 353 of 1092.
# RAC generation already complete for IMUTUG. Continuing to next MOF.
# The current MOF is IMUTUG. Number 354 of 1092.
# RAC generation already complete for IQECIS. Continuing to next MOF.
# The current MOF is IQECIS. Number 355 of 1092.
# RAC generation failed for IQUNAJ. Regenerating features for this MOF.
# The current MOF is IQUNAJ. Number 356 of 1092.
# RAC generation already complete for IRMOF-1-37. Continuing to next MOF.
# The current MOF is IRMOF-1-37. Number 357 of 1092.
# RAC generation already complete for IRMOF-1-38. Continuing to next MOF.
# The current MOF is IRMOF-1-38. Number 358 of 1092.
# RAC generation already complete for IRMOF-1-39. Continuing to next MOF.
# The current MOF is IRMOF-1-39. Number 359 of 1092.
# RAC generation already complete for IRMOF-1-40. Continuing to next MOF.
# The current MOF is IRMOF-1-40. Number 360 of 1092.
# RAC generation already complete for IRMOF-3-42. Continuing to next MOF.
# The current MOF is IRMOF-3-42. Number 361 of 1092.
# RAC generation already complete for ITIPOS. Continuing to next MOF.
# The current MOF is ITIPOS. Number 362 of 1092.
# RAC generation already complete for IVEQEG. Continuing to next MOF.
# The current MOF is IVEQEG. Number 363 of 1092.
# RAC generation already complete for IXIKOR. Continuing to next MOF.
# The current MOF is IXIKOR. Number 364 of 1092.
# RAC generation already complete for IYATEI. Continuing to next MOF.
# The current MOF is IYATEI. Number 365 of 1092.
# RAC generation already complete for IZENEI. Continuing to next MOF.
# The current MOF is IZENEI. Number 366 of 1092.
# RAC generation already complete for IZENIM. Continuing to next MOF.
# The current MOF is IZENIM. Number 367 of 1092.
# RAC generation already complete for IZENOS. Continuing to next MOF.
# The current MOF is IZENOS. Number 368 of 1092.
# RAC generation already complete for IZENUY. Continuing to next MOF.
# The current MOF is IZENUY. Number 369 of 1092.
# RAC generation already complete for IZIKEJ. Continuing to next MOF.
# The current MOF is IZIKEJ. Number 370 of 1092.
# RAC generation already complete for JALLEQ. Continuing to next MOF.
# The current MOF is JALLEQ. Number 371 of 1092.
# RAC generation already complete for JALLIU. Continuing to next MOF.
# The current MOF is JALLIU. Number 372 of 1092.
# RAC generation already complete for JALLOA. Continuing to next MOF.
# The current MOF is JALLOA. Number 373 of 1092.
# RAC generation already complete for JASMEW. Continuing to next MOF.
# The current MOF is JASMEW. Number 374 of 1092.
# RAC generation already complete for JIZJIN. Continuing to next MOF.
# The current MOF is JIZJIN. Number 375 of 1092.
# RAC generation already complete for JIZWAS. Continuing to next MOF.
# The current MOF is JIZWAS. Number 376 of 1092.
# RAC generation already complete for JOCPIB. Continuing to next MOF.
# The current MOF is JOCPIB. Number 377 of 1092.
# RAC generation already complete for JOFZOV. Continuing to next MOF.
# The current MOF is JOFZOV. Number 378 of 1092.
# RAC generation already complete for JUC-110. Continuing to next MOF.
# The current MOF is JUC-110. Number 379 of 1092.
# RAC generation already complete for JUMZIC. Continuing to next MOF.
# The current MOF is JUMZIC. Number 380 of 1092.
# RAC generation already complete for JUMZOI. Continuing to next MOF.
# The current MOF is JUMZOI. Number 381 of 1092.
# RAC generation already complete for JUMZUO01. Continuing to next MOF.
# The current MOF is JUMZUO01. Number 382 of 1092.
# RAC generation already complete for KADLIN. Continuing to next MOF.
# The current MOF is KADLIN. Number 383 of 1092.
# RAC generation already complete for KADLOT. Continuing to next MOF.
# The current MOF is KADLOT. Number 384 of 1092.
# RAC generation already complete for KADLUZ. Continuing to next MOF.
# The current MOF is KADLUZ. Number 385 of 1092.
# RAC generation already complete for KAMPOG. Continuing to next MOF.
# The current MOF is KAMPOG. Number 386 of 1092.
# RAC generation already complete for KASDOA. Continuing to next MOF.
# The current MOF is KASDOA. Number 387 of 1092.
# RAC generation already complete for KAVJAT. Continuing to next MOF.
# The current MOF is KAVJAT. Number 388 of 1092.
# RAC generation already complete for KAVJEX. Continuing to next MOF.
# The current MOF is KAVJEX. Number 389 of 1092.
# RAC generation already complete for KAXQOR. Continuing to next MOF.
# The current MOF is KAXQOR. Number 390 of 1092.
# RAC generation already complete for KEBDIG. Continuing to next MOF.
# The current MOF is KEBDIG. Number 391 of 1092.
# RAC generation already complete for KEBDOM. Continuing to next MOF.
# The current MOF is KEBDOM. Number 392 of 1092.
# RAC generation already complete for KEQJEX. Continuing to next MOF.
# The current MOF is KEQJEX. Number 393 of 1092.
# RAC generation already complete for KETHEY01. Continuing to next MOF.
# The current MOF is KETHEY01. Number 394 of 1092.
# RAC generation already complete for KEWZAP. Continuing to next MOF.
# The current MOF is KEWZAP. Number 395 of 1092.
# RAC generation already complete for KEWZET. Continuing to next MOF.
# The current MOF is KEWZET. Number 396 of 1092.
# RAC generation already complete for KEWZOD. Continuing to next MOF.
# The current MOF is KEWZOD. Number 397 of 1092.
# RAC generation already complete for KEYMUY. Continuing to next MOF.
# The current MOF is KEYMUY. Number 398 of 1092.
# RAC generation already complete for KEYNAF. Continuing to next MOF.
# The current MOF is KEYNAF. Number 399 of 1092.
# RAC generation already complete for KINJOI. Continuing to next MOF.
# The current MOF is KINJOI. Number 400 of 1092.
# RAC generation already complete for KINJUO. Continuing to next MOF.
# The current MOF is KINJUO. Number 401 of 1092.
# RAC generation already complete for KINKAV. Continuing to next MOF.
# The current MOF is KINKAV. Number 402 of 1092.
# RAC generation already complete for KINKEZ. Continuing to next MOF.
# The current MOF is KINKEZ. Number 403 of 1092.
# RAC generation already complete for KINKID. Continuing to next MOF.
# The current MOF is KINKID. Number 404 of 1092.
# RAC generation already complete for KINKOJ. Continuing to next MOF.
# The current MOF is KINKOJ. Number 405 of 1092.
# RAC generation already complete for KINKUP. Continuing to next MOF.
# The current MOF is KINKUP. Number 406 of 1092.
# RAC generation already complete for KINLAW. Continuing to next MOF.
# The current MOF is KINLAW. Number 407 of 1092.
# RAC generation already complete for KIWRUE01. Continuing to next MOF.
# The current MOF is KIWRUE01. Number 408 of 1092.
# RAC generation already complete for KIYHOR. Continuing to next MOF.
# The current MOF is KIYHOR. Number 409 of 1092.
# RAC generation already complete for KIYHUX. Continuing to next MOF.
# The current MOF is KIYHUX. Number 410 of 1092.
# RAC generation already complete for KIYJAF. Continuing to next MOF.
# The current MOF is KIYJAF. Number 411 of 1092.
# RAC generation already complete for KIYJEJ. Continuing to next MOF.
# ...
# The primitive cell of TAQGOK could not be found.
# The primitive cell of SOSFEN could not be found.
# The primitive cell of TAQYER could not be found.
# The primitive cell of SOYWUZ could not be found.
# The primitive cell of TAQGUQ could not be found.
# The primitive cell of TAQYIV could not be found.
# The primitive cell of TAFTOM could not be found.
# The primitive cell of TAVQAJ could not be found.
# The primitive cell of TEWFUY could not be found.
# The primitive cell of TEWFUY01 could not be found.
# The primitive cell of TEWFOS could not be found.
# The primitive cell of TEBWII could not be found.
# The primitive cell of TEYHIP could not be found.
# The primitive cell of TIDSEE could not be found.
# The primitive cell of TIFBEP could not be found.
# The primitive cell of TIFCEQ could not be found.
# The primitive cell of TIKXAN could not be found.
# The primitive cell of TIFCOA could not be found.
# The primitive cell of TIFCIU could not be found.
# The primitive cell of TILBOH could not be found.
# The primitive cell of TIRLEM could not be found.
# The primitive cell of TIRLIQ could not be found.
# The primitive cell of TISJOW could not be found.
# The primitive cell of TISJUC could not be found.
# The primitive cell of TIZYEI could not be found.
# The primitive cell of TIZYIM could not be found.
# The primitive cell of UBIPAY could not be found.
# The primitive cell of TUTZOX could not be found.
# The primitive cell of TUTZUD could not be found.
# The primitive cell of UCEXAC could not be found.
# The primitive cell of TOVGAO could not be found.
# The primitive cell of TIFCAM could not be found.
# The primitive cell of UCOCUM could not be found.
# The primitive cell of UDANAQ could not be found.
# The primitive cell of UFAROJ could not be found.
# The primitive cell of UFARUP could not be found.
# The primitive cell of UFASAW could not be found.
# The primitive cell of UFASEA could not be found.
# The primitive cell of UGOFED could not be found.
# The primitive cell of UGOFUT could not be found.
# The primitive cell of TOVGES could not be found.
# The primitive cell of UKUBIM could not be found.
# The primitive cell of UKUBOS could not be found.
# The primitive cell of UKUBUY could not be found.
# The primitive cell of UKIBIB could not be found.
# The primitive cell of UKUCAF could not be found.
# The primitive cell of ULASAD could not be found.
# The primitive cell of UGOCEA could not be found.
# The primitive cell of ULASEH could not be found.
# The primitive cell of UNABER could not be found.
# The primitive cell of UNABIV could not be found.
# The primitive cell of UMCM-1 could not be found.
# The primitive cell of UMCM-150 could not be found.
# The primitive cell of UGOCAW could not be found.
# The primitive cell of UNABOB could not be found.
# The primitive cell of UNINEL could not be found.
# The primitive cell of UNINIP could not be found.
# The primitive cell of UNINOV could not be found.
# The primitive cell of UNINUB could not be found.
# The primitive cell of UNIPAJ could not be found.
# The primitive cell of UNIPEN could not be found.
# The primitive cell of UQOWUU could not be found.The primitive cell of UQEGII could not be found.
#
# The primitive cell of UVARIT could not be found.
# The primitive cell of UTSA-16 could not be found.
# The primitive cell of USAHAZ could not be found.
# The primitive cell of UVEWIC could not be found.
# The primitive cell of UZIGOB could not be found.
# The primitive cell of UXOHOG could not be found.
# The primitive cell of UVUFUN could not be found.
# The primitive cell of UiO-66-Br could not be found.
# The primitive cell of UiO-2,6-NDC could not be found.
# The primitive cell of UiO-66-Br2 could not be found.
# The primitive cell of UiO-1,4-NDC could not be found.
# The primitive cell of UiO-66-CF3 could not be found.
# The primitive cell of UiO-66-CO2H could not be found.
# The primitive cell of UiO-66-CO2H_2 could not be found.
# The primitive cell of UiO-66-Cl2 could not be found.
# The primitive cell of UQEGEE could not be found.
# The primitive cell of UiO-66-DM could not be found.
# The primitive cell of UiO-66-F could not be found.
# The primitive cell of UiO-66-F2 could not be found.
# The primitive cell of UiO-66-I could not be found.
# The primitive cell of UiO-66-MM could not be found.
# The primitive cell of UiO-66-NH2 could not be found.
# The primitive cell of UiO-66-NO2 could not be found.
# The primitive cell of UiO-66-OMe_2 could not be found.
# The primitive cell of UiO-66 could not be found.
# The primitive cell of UiO-66-SO3H could not be found.
# The primitive cell of UiO-67 could not be found.
# The primitive cell of UiO-BPY could not be found.
# The primitive cell of VAGMAT could not be found.
# The primitive cell of VASGII could not be found.
# The primitive cell of VASGOO could not be found.
# The primitive cell of VEHLEA01 could not be found.
# The primitive cell of VASGUU could not be found.
# The primitive cell of VEMHOL could not be found.
# The primitive cell of VEMHIF could not be found.
# The primitive cell of VEPDEB could not be found.
# The primitive cell of VIDWAI could not be found.
# The primitive cell of VEQBID could not be found.
# The primitive cell of VIDWIQ could not be found.
# The primitive cell of VOCKUT could not be found.
# The primitive cell of VOCNOQ could not be found.
# The primitive cell of VOCQAF could not be found.
# The primitive cell of VOCQEJ could not be found.
# The primitive cell of VOFSIU could not be found.
# The primitive cell of VOFSAM could not be found.
# The primitive cell of VOFSOA could not be found.
# The primitive cell of VOFSUG could not be found.
# The primitive cell of VOPCEK could not be found.
# The primitive cell of VOFSEQ could not be found.
# The primitive cell of VOFTAN could not be found.
# The primitive cell of VOPJAN could not be found.
# The primitive cell of VOPHUF could not be found.
# The primitive cell of VOPVIH could not be found.
# The primitive cell of VOPVON could not be found.
# The primitive cell of VOPVUT could not be found.
# The primitive cell of VOPWAA could not be found.
# The primitive cell of VOPCIO could not be found.
# The primitive cell of VOPWII could not be found.
# The primitive cell of VOPWEE could not be found.
# The primitive cell of VOPWOO could not be found.
# The primitive cell of VOQJOC could not be found.
# The primitive cell of ValZnCl could not be found.
# The primitive cell of ValZnFor could not be found.
# The primitive cell of WABVOL could not be found.
# The primitive cell of WABVUR could not be found.
# The primitive cell of TOWPEC could not be found.
# The primitive cell of WABWAY could not be found.
# The primitive cell of WAFKEU02 could not be found.
# The primitive cell of WABWEC could not be found.
# The primitive cell of WAJHUM could not be found.
# The primitive cell of WASNIO could not be found.
# The primitive cell of WASNOU could not be found.
# The primitive cell of WASPAI could not be found.
# The primitive cell of WASNUA could not be found.
# The primitive cell of WAZPOE could not be found.
# The primitive cell of WEFXEM could not be found.
# The primitive cell of WEFXIQ could not be found.
# The primitive cell of WEHPIJ could not be found.
# The primitive cell of WEHPOP could not be found.
# The primitive cell of WEHQAC could not be found.
# The primitive cell of WEHQEG could not be found.
# The primitive cell of WEHQUW could not be found.
# The primitive cell of WEHQOQ could not be found.
# The primitive cell of WEHQOQ01 could not be found.
# The primitive cell of WEHRAD could not be found.
# The primitive cell of WEHREH could not be found.
# The primitive cell of WEHRIL could not be found.
# The primitive cell of VAHTUW could not be found.
# The primitive cell of WISVEB could not be found.
# The primitive cell of WIKGII could not be found.
# The primitive cell of WEXSEZ could not be found.
# The primitive cell of WITFEM could not be found.
# The primitive cell of WIYFAM could not be found.
# The primitive cell of WOLRIZ could not be found.
# The primitive cell of WITFOW could not be found.
# The primitive cell of WITFIQ could not be found.
# The primitive cell of WOZGUP could not be found.
# The primitive cell of WUSGIC could not be found.
# The primitive cell of WUSGOI could not be found.
# The primitive cell of WOLYON could not be found.
# The primitive cell of WUTBAQ could not be found.
# The primitive cell of WUTBEU could not be found.
# The primitive cell of XACFAJ could not be found.
# The primitive cell of XACFEN could not be found.
# The primitive cell of XALDAS could not be found.
# The primitive cell of XANMUX could not be found.
# The primitive cell of WOLREV could not be found.
# The primitive cell of XANZAQ could not be found.
# The primitive cell of XALXUF01 could not be found.
# The primitive cell of XAVQIU01 could not be found.
# The primitive cell of XAPFUS could not be found.
# The primitive cell of XAPGAZ could not be found.
# The primitive cell of XEJJEC could not be found.
# The primitive cell of XEJJIG could not be found.
# The primitive cell of XAPGED could not be found.
# The primitive cell of XEGJIE02 could not be found.
# The primitive cell of XEJJOM could not be found.
# The primitive cell of XAPGIH could not be found.
# The primitive cell of XICXAK could not be found.
# The primitive cell of XICXEO could not be found.
# The primitive cell of XICXOY could not be found.
# The primitive cell of WUHCUZ could not be found.
# The primitive cell of XICXUE could not be found.
# The primitive cell of XOFTES could not be found.
# The primitive cell of XOFTIW could not be found.
# The primitive cell of XOFTOC could not be found.
# The primitive cell of XUMFIW could not be found.
# The primitive cell of XICYAL could not be found.
# The primitive cell of XUNJEW could not be found.
# The primitive cell of XUMFOC could not be found.
# The primitive cell of YAHPED could not be found.
# The primitive cell of YATDUV could not be found.
# The primitive cell of YACWAC could not be found.
# The primitive cell of YAHPON could not be found.
# The primitive cell of YEGCEU could not be found.
# The primitive cell of YEGCIY could not be found.
# The primitive cell of YEGDAR could not be found.
# The primitive cell of YEGCOE could not be found.
# The primitive cell of YEGTAG could not be found.
# The primitive cell of YEGSUZ could not be found.
# The primitive cell of XICXIS could not be found.
# The primitive cell of YEGCUK could not be found.
# The primitive cell of YEGTEK could not be found.
# The primitive cell of YIKGEF01 could not be found.
# The primitive cell of YEZKIZ could not be found.
# The primitive cell of YIZJEY could not be found.
# The primitive cell of XALBUI could not be found.
# The primitive cell of YOYNOR could not be found.
# The primitive cell of YOYNUX could not be found.
# The primitive cell of YOYPAF could not be found.
# The primitive cell of YOYPEJ could not be found.
# The primitive cell of YOYPIN could not be found.
# The primitive cell of YOYPOT could not be found.
# The primitive cell of YEMGED could not be found.
# The primitive cell of YOYPUZ could not be found.
# The primitive cell of YOYQAG could not be found.
# The primitive cell of YOYQEK could not be found.
# The primitive cell of YOZROW could not be found.
# The primitive cell of YOYQIO could not be found.
# The primitive cell of YOYQOU could not be found.
# RAC generation failed for YEZKIZ. Continuing to next MOF.
# The primitive cell of YUQMOO could not be found.
# The primitive cell of YUQMUU could not be found.
# The primitive cell of ZASJAG could not be found.
# The primitive cell of YUQNAB could not be found.
# The primitive cell of YUQQEI could not be found.
# The primitive cell of WUPTUY could not be found.
# The primitive cell of YUKMOI could not be found.
# The primitive cell of YUKMUO could not be found.
# The primitive cell of YUKBUD could not be found.
# The primitive cell of ZEVWII could not be found.
# The primitive cell of YUKBOX could not be found.
# The primitive cell of YUKCAK could not be found.
# The primitive cell of ZEVWOO could not be found.
# The primitive cell of YUKBIR could not be found.
# The primitive cell of ZIF-7 could not be found.
# The primitive cell of ZIF-8 could not be found.
# The primitive cell of ZIF-90 could not be found.
# The primitive cell of WUPVAG could not be found.
# The primitive cell of ZOZHIH could not be found.
# The primitive cell of ZOZHUT could not be found.
# The primitive cell of ZOZJAB could not be found.
# The primitive cell of ZOZJEF could not be found.
# The primitive cell of ZOZJIJ could not be found.
# The primitive cell of ZOZJOP could not be found.
# The primitive cell of ZZZRNQ02 could not be found.
# The primitive cell of ZULNAX could not be found.
# The primitive cell of ZIF-11 could not be found.
# The primitive cell of ZZZSDW03 could not be found.
# The primitive cell of Zn-DMOF-A could not be found.
# The primitive cell of Zn-DMOF-Br could not be found.
# The primitive cell of Zn-DMOF-DM could not be found.
# The primitive cell of ZOZHON could not be found.
# The primitive cell of YOYZUJ could not be found.
# The primitive cell of Zn-DMOF-DM0_5 could not be found.
# The primitive cell of Zn-DMOF-MM could not be found.
# The primitive cell of Zn-DMOF-MM0_5 could not be found.
# The primitive cell of Zn-DMOF-NH2 could not be found.
# The primitive cell of Zn-DMOF-NO2 could not be found.
# The primitive cell of Zn-DMOF-Cl2 could not be found.
# The primitive cell of Zn-DMOF-OH could not be found.
# The primitive cell of Zn-DMOF-TF could not be found.
# The primitive cell of Zn-DMOF-TM could not be found.
# The primitive cell of Zn-DMOF-TM0_5 could not be found.
# The primitive cell of Zn-DMOF-option2 could not be found.
# The primitive cell of Zn-DMOF_NO2_2 could not be found.
# The primitive cell of Zn-MOF-508-72 could not be found.
# The primitive cell of Zn-MOF-508-TM could not be found.
# The primitive cell of Zn-MOF-508 could not be found.
# The primitive cell of Zn-NDC could not be found.
# The primitive cell of Zn-MOF-74 could not be found.
# The primitive cell of Zn2L4 could not be found.
# The primitive cell of Zn-slash-Co-BTEC could not be found.
# The primitive cell of Zn2_2-6-NDC_2_2-2-dimethyl-BPY could not be found.
# The primitive cell of ZnPO3 could not be found.
# The primitive cell of Zn6_IDC_4_OH_2_HPRZ_2 could not be found.
# The primitive cell of Zn3_BTP_2 could not be found.
# The primitive cell of Zr-DMBDC could not be found.
# The primitive cell of Zn3_BPDC_3_2-2-dimethyl-BPY could not be found.
# The primitive cell of Zn_1-3-BDP could not be found.
# The primitive cell of Zr6O6_ABDC-Cl2_12 could not be found.
# The primitive cell of dut-69-zr could not be found.
# The primitive cell of Zr6O6_ABDC_12 could not be found.
# The primitive cell of mil-110-al could not be found.
# The primitive cell of mil-125-nh2 could not be found.
# The primitive cell of mil-140a could not be found.
# The primitive cell of mil-125-ti could not be found.
# The primitive cell of mil-140b could not be found.
# The primitive cell of Zn-TTC could not be found.
# The primitive cell of mil-140c could not be found.
# The primitive cell of mil-140d could not be found.
# The primitive cell of mil-47-f could not be found.
# The primitive cell of mil-47 could not be found.
# The primitive cell of mil-53-al could not be found.
# The primitive cell of mil-53-cr could not be found.
# The primitive cell of mil-53-f-al could not be found.
# The primitive cell of mil-96 could not be found.
# The primitive cell of ZODXEX could not be found.
# The primitive cell of dut-67-hf could not be found.
# The primitive cell of dut-67-zr could not be found.
# The primitive cell of ZODXAT could not be found.
# The primitive cell of ZODXIB could not be found.
# The primitive cell of dut-51-zr could not be found.
# The primitive cell of dut-51-hf could not be found.
# The primitive cell of mil-100-fe could not be found.
# The primitive cell of mil-100-al could not be found.
# The primitive cell of mil-100-cr could not be found.
# The primitive cell of UDEMEW could not be found.
# The primitive cell of mil-101-cr-a could not be found.
# The primitive cell of mil-101-nh2 could not be found.
# The primitive cell of mil-101-no2 could not be found.
# The primitive cell of mil-101-so3h could not be found.
# The primitive cell of dut-68-hf could not be found.
# The primitive cell of dut-68-zr could not be found.
# unsuccessful_featurizations is ['IQUNAJ', 'YEZKIZ']

# %%
from pathlib import Path
import pandas as pd

# 1. Check if the final output CSV exists
clean_cif_dir = Path("./CGCNN_MT/data/WS24/clean_cifs")
output_csv = Path("./CGCNN_MT/data/WS24/RAC_and_zeo_features.csv")

if output_csv.exists():
    df = pd.read_csv(output_csv)
    total_cifs = len(list(clean_cif_dir.glob("*.cif")))
    print(f"✓ Output file exists: {len(df)} MOFs processed out of {total_cifs} CIFs")
    if len(df) == total_cifs:
        print("✓ Feature generation completed fully!")
    else:
        print(f"⚠ Missing features for {total_cifs - len(df)} MOFs")
else:
    print("✗ Output CSV not found - feature generation may not have completed")

# 2. Check feature_folders progress
work_dir = Path("./ML/featuring")
feature_folders = work_dir / "feature_folders"

if feature_folders.exists():
    processed = len(list(feature_folders.iterdir()))
    print(f"\nFeature folders created: {processed}")
else:
    print("Feature folders directory not found")

# 3. Check if process is still running (if you still have the process variable)
try:
    if process.poll() is None:
        print("\n⚠ Process is still running!")
    else:
        print(f"\nProcess finished with return code: {process.returncode}")
        if process.returncode != 0:
            stdout, stderr = process.communicate()
            print(f"Errors: {stderr.decode()}")
except NameError:
    print("\nProcess variable not available - check file outputs above")
# Out:
# ✓ Output file exists: 1090 MOFs processed out of 1092 CIFs
# ⚠ Missing features for 2 MOFs
#
# Feature folders created: 5240
#
# Process finished with return code: 0

# %% [markdown]
# ## Prepare WS24 dataset for CGCNN_MT

# %%
import pickle
import os
root_dir = Path("./CGCNN_MT/data/WS24")
cif_dir = root_dir/"clean_cifs"
logger = get_logger(filename=str(root_dir/f"prepare_data_{root_dir.name}.log"))

# Generate prepared data for WS24 dataset
failed_records = []
for cif_file in tqdm(list(cif_dir.glob("*.cif"))):
    g_file_name = cif_file.stem + ".graphdata"
    if (cif_dir/g_file_name).exists():
        with open(cif_dir/g_file_name, 'rb') as f:
            cif_id, atom_num, nbr_idx, nbr_dist, *_, cell_params = pickle.load(f)
        if nbr_idx.shape[0] / atom_num.shape[0] != 10.0:
            print(f"Number of neighbors is not 10 for {g_file_name}")
            os.remove(str(cif_dir/g_file_name))
            flag = make_prepared_data(cif_file, cif_dir, logger=logger, max_num_nbr=10, radius=8)
            if not flag:
                # print(f"Failed to generate graph data for {cif_file}")
                failed_records.append(cif_file.stem)
    else:
        flag = make_prepared_data(cif_file, cif_dir, logger=logger, max_num_nbr=10, radius=8)
        if not flag:
            # print(f"Failed to generate graph data for {cif_file}")
            failed_records.append(cif_file.stem)
            continue
print("Failed records:", len(failed_records))
# Out:
# 100%|██████████| 1092/1092 [00:00<00:00, 1674.37it/s]
# Failed records: 0

# %%
if len(failed_records) > 0:
    with open(tgt_root_dir/"mofs_prepare_failed.txt", "w") as f:
        f.write("\n".join(failed_records))

# %%
print(len(list(cif_dir.glob('*.cif'))))
print(len(list(cif_dir.glob('*.graphdata'))))
# Out:
# 1092
# 1092

# %% [markdown]
# ## Split the WS24 dataset into training, validation, and test sets

# %%
failed_records = []
in_df = pd.read_csv(src_csv)
in_df.insert(3, "water4_label", in_df["water_label"].astype(int))
in_df["water_label"] = in_df["water4_label"].apply(lambda x: 1 if x > 2 else 0)
in_df = in_df[~in_df['MOF_name'].isin(failed_records)]
in_df.rename(columns={"MOF_name": "MofName"}, inplace=True)
print(in_df.shape)
in_df.head(2)
# Out:
# (1092, 166)
#   MofName data_set  water_label  water4_label  acid_label  base_label  \
# 0  ACOFUU    WS24s            0             2           0           0
# 1  ACOGAB    WS24s            0             2           0           0
#
#    boiling_label       Di       Df      Dif  ...  f-lig-T-2  f-lig-T-3  \
# 0              0  7.99458  6.67411  7.99458  ...     1696.0     2024.0
# 1              0  5.20086  3.89327  4.83563  ...     1696.0     2024.0
#
#    f-lig-Z-0  f-lig-Z-1  f-lig-Z-2  f-lig-Z-3  f-lig-chi-0  f-lig-chi-1  \
# 0     2032.0     4616.0     6536.0     7248.0     540.5536     1176.932
# 1     2032.0     4616.0     6536.0     7248.0     540.5536     1176.932
#
#    f-lig-chi-2  f-lig-chi-3
# 0    1966.5344    2565.1968
# 1    1966.5344    2565.1968
#
# [2 rows x 166 columns]

# %%
def split_train_test(df, test_size=0.1, group_column="", random_state=0):
    """Split the dataset into train and test sets."""
    if group_column:
        train_index, test_index = train_test_split(df.index, test_size=test_size, stratify=df[group_column], random_state=random_state)
    else:
        train_index, test_index = train_test_split(df.index, test_size=test_size, random_state=random_state)
    print(f'Train test split successfully: train/test = {len(train_index)}/{len(test_index)}')
    return train_index, test_index

# %%
for lb in in_df["water4_label"].unique():
    print(lb, len(in_df[in_df["water4_label"] == lb]))
# Out:
# 2 350
# 4 98
# 3 555
# 1 89

# %%
random_seed = 42

label_cols = ['water_label', 'acid_label', 'base_label', 'boiling_label']

train_df, test_df = train_test_split(in_df, test_size=0.2, stratify=in_df[label_cols], random_state=random_seed)

train_df, val_df = train_test_split(train_df, test_size=0.2, stratify=train_df[label_cols], random_state=random_seed)

train_df.insert(2, "Partition", "train")
val_df.insert(2, "Partition", "val")
test_df.insert(2, "Partition", "test")

total_df = pd.concat([train_df, val_df, test_df])
ratio_dict = {}
for col in label_cols + ["water4_label"]:
    for lb in total_df[col].unique():
        split_ratios = []
        for split in ["train", "val", "test"]:
            sub_df = total_df.loc[(total_df[col] == lb) & (total_df["Partition"] == split)]
            sub_ratio = len(sub_df) / len(total_df.loc[(total_df[col] == lb)])
            split_ratios.append([sub_ratio, len(sub_df)])
        ratio_dict[f"{col}_{lb}(train/val/test)"] = ' : '.join([f"{c}({r:.2f})" for r, c in split_ratios])
for k, v in ratio_dict.items():
    print(f"{k}: {v}")
# Out:
# water_label_1(train/val/test): 417(0.64) : 105(0.16) : 131(0.20)
# water_label_0(train/val/test): 281(0.64) : 70(0.16) : 88(0.20)
# acid_label_0(train/val/test): 642(0.64) : 161(0.16) : 201(0.20)
# acid_label_1(train/val/test): 56(0.64) : 14(0.16) : 18(0.20)
# base_label_0(train/val/test): 658(0.64) : 165(0.16) : 207(0.20)
# base_label_1(train/val/test): 40(0.65) : 10(0.16) : 12(0.19)
# boiling_label_0(train/val/test): 657(0.64) : 163(0.16) : 206(0.20)
# boiling_label_1(train/val/test): 41(0.62) : 12(0.18) : 13(0.20)
# water4_label_3(train/val/test): 351(0.63) : 88(0.16) : 116(0.21)
# water4_label_2(train/val/test): 220(0.63) : 59(0.17) : 71(0.20)
# water4_label_4(train/val/test): 66(0.67) : 17(0.17) : 15(0.15)
# water4_label_1(train/val/test): 61(0.69) : 11(0.12) : 17(0.19)

# %%
total_df.head()
# Out:
#        MofName data_set Partition  water_label  water4_label  acid_label  \
# 364     KINKUP    WS24s     train            1             3           0
# 709     TIZYIM    WS24s     train            1             3           0
# 886     YUKBOX    WS24s     train            0             2           0
# 477     NABNIO    WS24s     train            1             3           0
# 986  Ni_HPTZ_2    WS14s     train            1             3           1
#
#      base_label  boiling_label        Di       Df  ...    f-lig-T-2  \
# 364           0              0   3.75964  1.31922  ...   575.428571
# 709           0              0   4.24601  3.52063  ...  3086.000000
# 886           0              0  16.40548  6.25440  ...  1646.571429
# 477           0              0   4.17211  3.43410  ...   429.000000
# 986           0              1   5.28442  4.83200  ...   414.000000
#
#        f-lig-T-3    f-lig-Z-0    f-lig-Z-1    f-lig-Z-2    f-lig-Z-3  \
# 364   555.142857   816.285714  1839.142857  2564.571429  2361.714286
# 709  2388.000000   817.000000  2248.000000  3380.000000  3306.000000
# 886  2096.142857  1518.000000  3450.857143  5413.714286  6724.285714
# 477   455.000000   646.000000  1322.000000  1837.000000  1806.000000
# 986   417.000000   859.500000  1946.000000  2409.000000  2106.000000
#
#      f-lig-chi-0  f-lig-chi-1  f-lig-chi-2  f-lig-chi-3
# 364   200.095571   434.170857   681.305829   785.542829
# 709   246.511900   688.021000  1509.685400  1817.937000
# 886   423.364586   911.453786  1621.134086  2192.630786
# 477   159.829900   323.130500   509.890300   615.175500
# 986   156.341700   320.427800   519.717000   569.667000
#
# [5 rows x 167 columns]

# %%
total_df.to_csv(tgt_root_dir/'id_prop_feat.csv', index=False)

# %% [markdown]
# ### Reneragete zeo++ and RACs features for WS24 datasets.

# %%
df_new = pd.read_csv('./CGCNN_MT/data/WS24/RAC_and_zeo_features.csv')
df = pd.read_csv("./CGCNN_MT/data/WS24/id_prop_feat.csv")
# df.insert(3, "water4_label", df["water_label"])
# df["water_label"] = df["water4_label"].apply(lambda x: 0 if x<=2 else 1)
print(df_new.shape, df.shape)
df_new.drop(columns=['cif_file'], inplace=True)
df_new.rename(columns={'name': 'MofName'}, inplace=True)
df.rename(columns={'MOF_name': 'MofName', "split": "Partition"}, inplace=True)

id_prop_cols = ["MofName", "Partition", "water_label", "water4_label", "acid_label", "base_label", "boiling_label"]
df_new = df[id_prop_cols].merge(df_new, on="MofName", how="left")

df_new.to_csv("./CGCNN_MT/data/WS24/RAC_and_zeo_features_with_id_prop.csv", index=False)
# Out:
# (1090, 192) (1092, 167)
